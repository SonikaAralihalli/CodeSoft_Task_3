# %%
import random
a=int(input("Enter length of passward"))
g=["@","#","$","^","*"]
if a%2==0:
    k=int(a/2)
elif a/2!=0:
    k=int((a/2))
    l = random.choice(g)
    print(l,end="")
for i in range(0,k):
    d = random.randint(0, 9 )
    l = random.choice(g)
    print(d,l,end="")
# Out:
# Enter length of passward6
# 9 ^6 #8 #
